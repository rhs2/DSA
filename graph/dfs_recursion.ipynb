# %% [markdown]
# # Traversal DFS- depth first search recursion

# %%
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# print that node and add it to visited
# then loop throgh the list graph[node]
# again use dfs recursion on that loop
def dfs_recursion(node, graph, visited):
    if node not in graph:
        print("node not present")
        return
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for i in graph[node]:
            dfs_recursion(i, graph, visited)
            
            
visited = set()
                

graph = {}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_node("K")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")

dfs_recursion("A",graph, visited)
print()
# to check if the given graph is connected graph or disconnected graph
#1. loop through the list(graph)
#2. if i is not in visited that means graph is disconnected graph
#3. we will use else with for loop, given graph is connected
# for i in list(graph):
#     if i not in visited:
#         print("given graph is disconnected graph")
#         break
# else:
#     print('given graph is connected graph')

# # traverse through disconnected graph
# for i in list(graph):
#     if i not in visited:
#         print("next connected components")
#         dfs_recursion(i, graph, visited)
# Out:
# A B D E F G H C

# %% [markdown]
# ## Check graph is disconnected or connected

# %%
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# print that node and add it to visited
# then loop throgh the list graph[node]
# again use dfs recursion on that loop
def dfs_recursion(node, graph, visited):
    if node not in graph:
        print("node not present")
        return
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for i in graph[node]:
            dfs_recursion(i, graph, visited)
            
            
visited = set()
                

graph = {}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_node("K")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")

dfs_recursion("A",graph, visited)
print()
# to check if the given graph is connected graph or disconnected graph
#1. loop through the list(graph)
#2. if i is not in visited that means graph is disconnected graph
#3. we will use else with for loop, given graph is connected
for i in list(graph):
    if i not in visited:
        print("given graph is disconnected graph")
        break
else:
    print('given graph is connected graph')

# # traverse through disconnected graph
# for i in list(graph):
#     if i not in visited:
#         print("next connected components")
#         dfs_recursion(i, graph, visited)
# Out:
# A B D E F G H C
# given graph is disconnected graph

# %%
print(graph)
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'D'], 'C': ['A'], 'D': ['B', 'E', 'F'], 'E': ['D', 'F'], 'F': ['E', 'D', 'G', 'H'], 'G': ['F', 'H'], 'H': ['G', 'F']}

# %% [markdown]
# ## traversal through disconnected graph

# %%
# traversal through disconnected graph
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# print that node and add it to visited
# then loop throgh the list graph[node]
# again use dfs recursion on that loop
def dfs_recursion(node, graph, visited):
    if node not in graph:
        print("node not present")
        return
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for i in graph[node]:
            dfs_recursion(i, graph, visited)
            
            
visited = set()
                

graph = {}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_node("K")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")

dfs_recursion("A",graph, visited)
print()
# to check if the given graph is connected graph or disconnected graph
#1. loop through the list(graph)
#2. if i is not in visited that means graph is disconnected graph
#3. we will use else with for loop, given graph is connected
# for i in list(graph):
#     if i not in visited:
#         print("given graph is disconnected graph")
#         break
# else:
#     print('given graph is connected graph')

# # traverse through disconnected graph
for i in list(graph):
    if i not in visited:
        print("next connected components")
        dfs_recursion(i, graph, visited)
# Out:
# A B D E F G H C
# next connected components
# K

# %% [markdown]
# ## check if the graph is strongly connected or weakly connected

# %%
# traversal through disconnected graph
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        graph1[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
        graph1[v1].append(v2)
        graph1[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# print that node and add it to visited
# then loop throgh the list graph[node]
# again use dfs recursion on that loop
def dfs_recursion(node, graph, visited):
    if node not in graph:
        print("node not present")
        return
    if node not in visited:
        print(node, end=" ")
        visited.add(node)
        for i in graph[node]:
            dfs_recursion(i, graph, visited)
            
            
visited = set()
visited1 = set()
                

graph = {}
graph1={}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_node("K")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")

# 1. run the dfs algo on the given graph
# 2. loop through graph if nodes not present in the visited set then graph is weakly connected graph and break
# 3.else, reverse the direction of edges and graph make a new graph1 and visited1
# 4. run the dfs function again on them
# 5. check now visited == visited1 if yes, graph is strongly connected, if not graph is weakly connected
dfs_recursion("A", graph, visited)
print()
for i in list(graph):
    if i not in visited:
        print("given graph is weakly connected graph")
        break
else: 
    dfs_recursion("A", graph1, visited1)
    if visited==visited1:
        print("given graph strongly connected graph")
    else:
        print("given graph is weakly connected graph")

# on the strongly connected we are getting 2 ouputs of the recursion because we are using two ways undirected data.
# Out:
# A B D E F G H C
# given graph is weakly connected graph
