# %% [markdown]
# # DFS- ITERATIVE

# %%
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)


# for the dfs iterative we will use adj list
# also use stack and visited set to count the nodes
# 1. append that staring node to stack
# 2. pop from stack
# 3. check if popped element already in the visited
# 4. if not print that node and add it to visited set
# 5. loop through graph [current node]
# 6. add those iterative in the stack
def dfs_iterative(node, graph):
    if node not in graph:
        print("not present in the graph")
        return
    stack = []
    stack.append(node)
    visited = set()
    while stack:
        current = stack.pop()
        if current not in visited: 
            print(current, end=" ")
            visited.add(current)
            for i in graph[current]:
                stack.append(i)

graph = {}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")
dfs_iterative("A",graph)
# Out:
# A C B D F H G E

# %% [markdown]
# ## to check graph is connected graph or disconnected graph

# %%
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)


# for the dfs iterative we will use adj list
# also use stack and visited set to count the nodes
# 1. append that staring node to stack
# 2. pop from stack
# 3. check if popped element already in the visited
# 4. if not print that node and add it to visited set
# 5. loop through graph [current node]
# 6. add those iterative in the stack
def dfs_iterative(node, graph, visited):
    if node not in graph:
        print("not present in the graph")
        return
    stack = []
    stack.append(node)
    while stack:
        current = stack.pop()
        if current not in visited: 
            print(current, end=" ")
            visited.add(current)
            for i in graph[current]:
                stack.append(i)
visited= set()
graph = {}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_node("K")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")
dfs_iterative("A",graph, visited)

for i in list(graph):
    if i not in visited:
        print("given graph is disconnected graph")
        break
else:
    print("given graph is connected graph")
# Out:
# A C B D F H G E given graph is disconnected graph

# %% [markdown]
# # traversal a disconnected graph

# %%
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)


# for the dfs iterative we will use adj list
# also use stack and visited set to count the nodes
# 1. append that staring node to stack
# 2. pop from stack
# 3. check if popped element already in the visited
# 4. if not print that node and add it to visited set
# 5. loop through graph [current node]
# 6. add those iterative in the stack
def dfs_iterative(node, graph, visited):
    if node not in graph:
        print("not present in the graph")
        return
    stack = []
    stack.append(node)
    while stack:
        current = stack.pop()
        if current not in visited: 
            print(current, end=" ")
            visited.add(current)
            for i in graph[current]:
                stack.append(i)
visited= set()
graph = {}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_node("K")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")
dfs_iterative("A",graph, visited)

for i in list(graph):
    if i not in visited:
        print("next component")
        dfs_iterative(i, graph, visited)
# Out:
# A C B D F H G E next component
# K

# %% [markdown]
# ## to check graph is strongly connected or weakly connected

# %%
# for the dfs recursion we will use adj list
# initially, for the parameter we need a starting node, and visited dictionary to count up if the nodes already visited or not
# UNDIRECTED AND UNWEIGHTED GRAPH
def add_node(v):
    if v in graph:
        print("vertex are already present")
    else:
        graph[v]= []
        graph1 [v] =[]
        
def add_edge(v1, v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].append(v2)
        graph[v2].append(v1)
        graph1[v1].append(v2)
        graph1[v2].append(v1)
def del_node(v):
    if v not in graph:
        print("not present in the graph")
    else:
        graph.pop(v)
        for i in graph:
            list1= graph[i]
            if v in list1:
                list1.remove(v)
def del_edge(v1,v2):
    if v1 not in graph:
        print("not present in the graph")
    elif v2 not in graph:
        print("not present in the graph")
    else:
        graph[v1].remove(v2)
        graph[v2].remove(v1)


# for the dfs iterative we will use adj list
# also use stack and visited set to count the nodes
# 1. append that staring node to stack
# 2. pop from stack
# 3. check if popped element already in the visited
# 4. if not print that node and add it to visited set
# 5. loop through graph [current node]
# 6. add those iterative in the stack
def dfs_iterative(node, graph, visited):
    if node not in graph:
        print("not present in the graph")
        return
    stack = []
    stack.append(node)
    while stack:
        current = stack.pop()
        if current not in visited: 
            print(current, end=" ")
            visited.add(current)
            for i in graph[current]:
                stack.append(i)
visited= set()
visited1 = set()
graph = {}
graph1={}
add_node("A")
add_node("B")
add_node("C")
add_node("D")
add_node("E")
add_node("F")
add_node("G")
add_node("H")
add_edge("A", "B")
add_edge("A", "C")
add_edge("B", "D")
add_edge("D", "E")
add_edge("E", "F")
add_edge("D", "F")
add_edge("F", "G")
add_edge("G", "H")
add_edge("F", "H")
dfs_iterative("A",graph, visited)
print()
for i in list(graph):
    if i not in visited:
        print("given graph is a weakly connected graph")
        break
else:
    dfs_iterative("A", graph1, visited1)
    if visited == visited1:
        print("Given graph is strongly connected graph")
    else:
        print("given graph is weakly connected graph")
# on the strongly connected we are getting 2 ouputs of the recursion because we are using two ways undirected data.
# Out:
# A C B D F H G E
# A C B D F H G E Given graph is strongly connected graph
